# %%
import pandas as pd
import numpy as np

# %%
df_dados_homens = pd.read_csv('../../data/TirolaDataset/01 - Body Data.txt',sep='\t')
df_dados_homens.head(100)
# Out:
#     AGE  GENDER (1=M)  PULSE  SYSTOLIC  DIASTOLIC  HDL  LDL  WHITE   RED  \
# 0    43             0     80       100         70   73   68    8.7  4.80
# 1    57             1     84       112         70   35  116    4.9  4.73
# 2    38             0     94       134         94   36  223    6.9  4.47
# 3    80             1     74       126         64   37   83    7.5  4.32
# 4    34             1     50       114         68   50  104    6.1  4.95
# ..  ...           ...    ...       ...        ...  ...  ...    ...   ...
# 95   64             0     74       120         72   61  121    4.2  4.49
# 96   28             1     54       128         72   39  123    5.2  5.05
# 97   33             0     74       114         78   40   85    6.5  4.49
# 98   58             1     84       128         74   36  118   12.6  5.80
# 99   18             1     72       128         66   60   84    3.3  4.13
#
#     PLATE  WEIGHT  HEIGHT  WAIST  ARM CIRC   BMI
# ...
